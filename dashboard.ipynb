# %%
# %sql
SELECT department_name, total_budget FROM filestore.gold.dept_monthly_budget

# %%
# %sql
SELECT department_name, count(*) as veteran_count 
FROM filestore.gold.employee_tenure_report 
GROUP BY department_name

# %%
# %sql
SELECT * FROM filestore.gold.employee_tenure_report ORDER BY tenure_years DESC
